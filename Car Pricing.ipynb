# %%
import pandas as pd
# Filters out warning messages. The filterwarnings() method is called with the argument "ignore" to ignore all warning messages.
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns
mpl.style.use('ggplot')

# %%
# Reads the CSV file 'car_data.csv' and storing the data in a DataFrame object named car_df.

car_df = pd.read_csv('car_data.csv')

# %%
# Gets the shape [num of rows, num of columns] of the dataframe.

car_df.shape
# Out:
# (892, 6)

# %%
# Returns the column names of the Dataframe car_df.

car_df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
# Returns the data related to cars.

car_df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Returns information about the dataframe.

car_df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
# Returns the total number of missing values (NaNs) in the 'year' column of the DataFrame.

car_df['year'].isna().sum()
# Out:
# 0

# %%
# Filters the DataFrame 'car_df' to only include the rows where the 'year' column contains numeric values.

car_df = car_df[car_df.year.str.isnumeric()]

# %%
# Converting the 'year' column of the DataFrame car_df from a string data type to an integer data type and assigns the converted 'year' column back to the DataFrame car_df, replacing the original 'year' column.

car_df ['year'] = car_df['year'].astype(int)
car_df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
# Returns an array of unique values in the 'year' column of the DataFrame. 

car_df ['year']. unique()
# Out:
# array([2007, 2006, 2018, 2014, 2015, 2012, 2013, 2016, 2010, 2017, 2008,
#        2011, 2019, 2009, 2005, 2000, 2003, 2004, 1995, 2002, 2001])

# %%
# Uses this Boolean mask to select all rows where the 'Price' column does not contain the string 'Ask For Price',filtering out any rows where the price is not provided and the filtered DataFrame is then assigned back to car_df

car_df = car_df[car_df['Price']!='Ask For Price']
car_df
# Out:
#                                        name    company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  5,75,000
# 6                                 Ford Figo       Ford  2012  1,75,000
# ..                                      ...        ...   ...       ...
# 886                    Toyota Corolla Altis     Toyota  2009  3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018  2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013  3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# ...

# %%
# Replaces all commas in the Price column with spaces and converts the resulting string values in the 'Price' column to integers.

car_df ['Price'] = car_df ['Price'].str.replace (',', '').astype(int)
car_df
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# ...

# %%
# Splits the 'kms_driven' column values by space character and selects the first element of each split using the str.split().str.get() method chain. Then, it replaces any comma present in the selected string with an empty string using str.replace() method. Finally, the updated values are assigned back to the 'kms_driven' column.

car_df ['kms_driven'] = car_df ['kms_driven'].str.split (' ').str.get(0).str.replace(',', '')
car_df
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
# Filters out the rows from the car_df DataFrame where the 'kms_driven' column values are non-numeric and returns only those rows where the 'kms_driven' column contains numeric values. .

car_df = car_df[car_df.kms_driven.str.isnumeric()]
car_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
## Converting the 'kms_driven' column of the DataFrame car_df from a string data type to an integer data type and assigns the converted 'kms_driven' column back to the DataFrame car_df, replacing the original 'kms_driven' column.

car_df ['kms_driven'] = car_df['kms_driven'].astype(int)
car_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 3         28000    Petrol
# 4         36000    Diesel
# ...

# %%
car_df = car_df[~car_df['fuel_type'].isna()]
car_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 3         28000    Petrol
# 4         36000    Diesel
# ...

# %%
# Takes the name column, which contains full names of cars, and keeps only the first three words of each name.

car_df ['name'] = car_df ['name'].str.split().str.slice(start=0, stop=3).str.join(' ')
car_df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
# Resets the index of the DataFrame car_df and drops the previous index. The resulting DataFrame is then assigned to the variable car_df.

car_df = car_df.reset_index(drop=True)
car_df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
# The relationship between the price and company  
# Plots a box plot of the price of cars for each company, with the company names on the x-axis and the price on the y-axis. The tick labels on the x-axis are rotated and aligned to the right.
plt.subplots(figsize = (15,7))
ax = sns.boxplot(x = 'company', y = 'Price', data = car_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40,ha = 'right')
plt.show();

# %% [markdown]
# ## 'x' is a pandas DataFrame that contains the input features, which are 'name', 'company', 'year', 'kms_driven', and 'fuel_type'. These features are chosen because they are likely to be important factors in determining the price of a car. 'y' is a pandas Series that contains the output target variable, which is 'Price'. This is the value that we want to predict using the input features. By splitting the data into x and y, we can use machine learning algorithms to train a model that can predict the price of a car based on its attributes. The model can then be used to make predictions on new, unseen data.

# %%
# Defines the input features and output target variable for a regression or prediction model that can be trained on a dataset of cars.

x = car_df[['name', 'company', 'year', 'kms_driven','fuel_type']]
y = car_df ['Price']

# %%
x
# Out:
#                        name   company  year  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 4                 Ford Figo      Ford  2012       41000    Diesel
# ..                      ...       ...   ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 812          Tata Indica V2      Tata  2009       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 814            Tata Zest XM      Tata  2018       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [816 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: Price, Length: 816, dtype: int64

# %% [markdown]
# # TRAINING AND TESTING

# %% [markdown]
# ## The test_size parameter is set to 0.2, which means that 20% of the data will be used for testing, and the remaining 80% will be used for training. The random state is not specified, which means that the data will be split randomly every time the code is run. After executing this code, we will have four new variables:
#
# - x_train: A pandas DataFrame containing 80% of the input features (chosen randomly) for training the model.
# - y_train: A pandas Series containing 80% of the output target variable (chosen randomly) for training the model.
# - x_test: A pandas DataFrame containing 20% of the input features (chosen randomly) for testing the model.
# - y_test: A pandas Series containing 20% of the output target variable (chosen randomly) for testing the model.

# %%
# Splits the data into training and testing sets for machine learning.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %% [markdown]
# # One HotEncoder

# %%
# Imports the OneHotEncoder class from the Scikit-learn preprocessing module. OneHotEncoder is a transformer that can be used to convert categorical data into numerical data.
from sklearn.preprocessing import OneHotEncoder

# Imports the make_column_transformer function from the Scikit-learn compose module. make_column_transformer is a function that can be used to create a transformer that applies different transformers to different columns of a dataset.
from sklearn.compose import make_column_transformer

# Imports the make_pipeline function from the Scikit-learn pipeline module. make_pipeline is a function that can be used to create a pipeline that applies a sequence of transformers and an estimator to the input data.
from sklearn.pipeline import make_pipeline

# Imports the r2_score function from the Scikit-learn metrics module. r2_score is a function that can be used to evaluate the performance of a regression model by computing the R-squared coefficient.
from sklearn.metrics import r2_score

# %%
# Creates an instance of the OneHotEncoder class and assigns it to the variable ohe.
ohe = OneHotEncoder()

# Fits the OneHotEncoder to the subset of columns in x that contain categorical variables: 'name', 'company', and 'fuel_type'. Fitting the OneHotEncoder means that it is learning the unique values of each categorical variable and creating a mapping from each value to a binary vector.
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
# Creates a pipeline that will transform the input data into a format that can be used by a machine learning algorithm. 
columns_trans = make_column_transformer((OneHotEncoder(categories = ohe.categories_), ['name','company','fuel_type']),
remainder = 'passthrough')

# %% [markdown]
# ### OneHotEncoder(categories = ohe.categories['name','company','fuel_type']) specifies the first step of the column transformer, which is to apply the OneHotEncoder to the columns 'name', 'company', and 'fuel_type'. The categories parameter of the OneHotEncoder is set to ohe.categories_, which is the list of unique values learned by the OneHotEncoder when it was fitted to the data in the previous step. This ensures that the OneHotEncoder maps each unique value to the same binary vector, even if the value does not appear in the current data.
# ### remainder = 'passthrough': This specifies that any columns that are not transformed by the first step of the column transformer should be passed through unchanged. In this case, the 'year', 'kms_driven', and 'mileage' columns are not categorical, so they will be included in the output of the column transformer without being transformed.

# %% [markdown]
# # LINEAR REGRESSION

# %%
# imports the LinearRegression class from the Scikit-learn library.

from sklearn.linear_model import LinearRegression

# %%
# Creates an instance of the LinearRegression class and assigns it to the variable lr.
lr = LinearRegression()

# %%
# creates a Scikit-learn Pipeline object that applies the column transformer columns_trans to the input data and then fits a linear regression model lr to the transformed data.
pipe = make_pipeline(columns_trans,lr)

# %%
# Fits the pipeline object pipe to the training data x_train and y_train.

pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %% [markdown]
# ### In machine learning, the process of "fitting" a model to data involves using an algorithm to learn the relationship between the input variables (x_train) and the output variable (y_train). The algorithm uses a set of parameters that are adjusted during the learning process in order to minimize the difference between the model's predictions and the actual values in the training data.
#
# ### By calling the fit method of the pipeline object, we train the linear regression model on the training data that has been preprocessed by the column transformer columns_trans. The pipeline applies the preprocessing steps (one-hot encoding and passing non-categorical columns through unchanged) to the input data, and then fits the linear regression model to the transformed data.
#
# ### After the pipeline has been fit to the training data, we can use it to make predictions on new data points by calling the predict method of the pipeline object. For example, we can use pipe.predict(x_test) to make predictions on a set of test data.

# %%
# Uses the fitted pipeline object pipe to make predictions on the test data x_test, and assigns the predicted values to the variable y_pred.

y_pred = pipe.predict(x_test)

# %%
y_pred
# Out:
# array([ 298553.69005074,  427915.69533855,  113080.79168844,
#         214741.07231745,  265455.84524693,  512292.57956724,
#         573868.59303334,  337867.80390192,  605001.18671744,
#         355080.78609653,  494547.56544034,  230763.54876842,
#         446730.86950763,  222982.39307985,  283315.84861658,
#         158547.49378745,  769639.23325077,  822578.89346687,
#         410105.45815014,  435931.44238096,  410105.45815014,
#         182946.59923162,  797278.58272225,  344940.03552472,
#         525600.19918893,  374112.47516372,  454950.22048946,
#         229997.46523834,  161362.16895227,  435931.44238096,
#         267542.94602264,  431363.79068568, 2358279.04668035,
#         153619.3894503 ,  363377.53782776,  186090.34703735,
#         -84146.08309697, 2358279.04668035, -156937.31776121,
#         167236.41190529,  556117.55533383,  770965.85497231,
#         384545.30157603,  188165.63499071,  225360.85993405,
# ...

# %%
# Calculates the R-squared coefficient of determination for a regression problem. 
r2_score(y_test,y_pred)
# Out:
# 0.5248519005455776

# %% [markdown]
# ### The R2 score, also known as the coefficient of determination, is a statistical metric that measures how well the predicted values from a regression model fit the actual values. The score ranges from 0 to 1, where a value of 1 indicates that the model perfectly predicts the response variable, and a value of 0 indicates that the model does not predict the response variable at all.

# %% [markdown]
# # FINDING THE MODEL WITH A RANDOM STATE OF TRAINSPLIT

# %%
scores = []
for i in range (1000):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = i)
    lr = LinearRegression()
    pipe = make_pipeline(columns_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred = pipe.predict (x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
scores
# Out:
# [0.5796482197434663,
#  0.4601888225906392,
#  0.08100410085151699,
#  0.5194514711962709,
#  0.705532114452551,
#  0.5611403541612814,
#  0.6571759153007581,
#  0.45700514822480787,
#  0.46792789288118597,
#  0.6994047125826983,
#  0.5705474404523603,
#  0.512671165271394,
#  0.45001726581385093,
#  0.5672403148144906,
#  0.5792442952808563,
#  0.6910838836518909,
#  0.445411829109574,
#  0.5118859463727443,
#  0.46009149165880947,
#  0.44590245705270914,
#  0.6964142720744,
#  0.34854575927785425,
#  0.7682908378192081,
#  0.5630187164284444,
#  0.454501968170671,
#  0.41251355505844967,
#  0.6343601824579244,
#  0.7558414418911032,
#  0.5249337615659126,
#  0.7276363928925773,
#  0.7275320591643444,
#  0.6873243421442854,
#  0.5628112839275572,
#  0.4904022218958628,
#  0.11034165779946326,
#  0.5972858612937985,
#  0.6282057746121502,
#  0.5225990518229866,
#  0.2071332696984851,
#  0.7177747491263684,
#  0.0815758019625843,
#  0.5958940401195771,
#  0.11779103108014755,
# ...

# %%
import numpy as np
np.argmax(scores)
# Out:
# 247

# %%
scores [np.argmax(scores)]
# Out:
# 0.8604198447904555

# %%
import pickle

# %%
pickle.dump (pipe, open('LinearRegressionModel.pkl', 'wb'))

# %%
pipe.predict (pd.DataFrame(columns = x_test.columns, data = np.array(['Maruti Suzuki Swift', 'Maruti', 2019,100, 'Petrol']).reshape(1,5)))
# Out:
# array([453164.61519839])
